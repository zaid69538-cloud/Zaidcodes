# %% [markdown]
# <a href="https://colab.research.google.com/github/zaid69538-cloud/Zaidcodes/blob/main/B2B_session_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#question
#1.can data about countries help us compare development overtime?
#2. can gdp per capita income be the only to judge acountries development?

#helthcare
#employement rates
#mortality rate
#literacy
#infra
#quality of life


#helthcare:
#mortality rate
#quality of doctors
#medicine
#healthcare infra
#vaccinatin coverage

#mortality rate:
#crude moratality rate
#lack of resources
#availability of ambulances
#infrant morality rate
#pregnat morality
#neonatal morality rate

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

url="https://raw.githubusercontent.com/plotly/datasets/master/gapminderDataFiveYear.csv"

df=pd.read_csv(url)


print(df.head())
print(df.shape)
print(df.columns)
print(df.info())
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# (1704, 6)
# Index(['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   year       1704 non-null   int64
#  2   pop        1704 non-null   float64
#  3   continent  1704 non-null   object
#  4   lifeExp    1704 non-null   float64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 80.0+ KB
# None

# %%
df=df.rename(columns={
    "lifeExp" : "life_expectancy",
    "pop" : "population",
    "gdpPercap" : "gdp_per_capita"
})

print(df.head())
print(df.columns)
# Out:
#        country  year  population continent  life_expectancy  gdp_per_capita
# 0  Afghanistan  1952   8425333.0      Asia           28.801      779.445314
# 1  Afghanistan  1957   9240934.0      Asia           30.332      820.853030
# 2  Afghanistan  1962  10267083.0      Asia           31.997      853.100710
# 3  Afghanistan  1967  11537966.0      Asia           34.020      836.197138
# 4  Afghanistan  1972  13079460.0      Asia           36.088      739.981106
# Index(['country', 'year', 'population', 'continent', 'life_expectancy',
#        'gdp_per_capita'],
#       dtype='object')

# %%
print("Missing values in each column:")
print(df.isna().sum())
print("Number of duplicate rows:",df.duplicated().sum())
# Out:
# Missing values in each column:
# country            0
# year               0
# population         0
# continent          0
# life_expectancy    0
# gdp_per_capita     0
# dtype: int64
# Number of duplicate rows: 0

# %%
dirty_demo = df.head(12).copy()
#deliberately introduce missing values for teaching practice

dirty_demo.loc[2,"life_expectancy"]=np.nan
dirty_demo.loc[5,"gdp_per_capita"]=np.nan

print(dirty_demo)
print(dirty_demo.isna().sum())

#fill mising numerical values using median

clean_demo = dirty_demo.copy()
clean_demo["life_expectancy"]=clean_demo["life_expectancy"].fillna(clean_demo["life_expectancy"].median())
clean_demo["gdp_per_capita"]=clean_demo["gdp_per_capita"].fillna(clean_demo["gdp_per_capita"].median())


print(clean_demo.isna().sum())
print(clean_demo)
# Out:
#         country  year  population continent  life_expectancy  gdp_per_capita
# 0   Afghanistan  1952   8425333.0      Asia           28.801      779.445314
# 1   Afghanistan  1957   9240934.0      Asia           30.332      820.853030
# 2   Afghanistan  1962  10267083.0      Asia              NaN      853.100710
# 3   Afghanistan  1967  11537966.0      Asia           34.020      836.197138
# 4   Afghanistan  1972  13079460.0      Asia           36.088      739.981106
# 5   Afghanistan  1977  14880372.0      Asia           38.438             NaN
# 6   Afghanistan  1982  12881816.0      Asia           39.854      978.011439
# 7   Afghanistan  1987  13867957.0      Asia           40.822      852.395945
# 8   Afghanistan  1992  16317921.0      Asia           41.674      649.341395
# 9   Afghanistan  1997  22227415.0      Asia           41.763      635.341351
# 10  Afghanistan  2002  25268405.0      Asia           42.129      726.734055
# 11  Afghanistan  2007  31889923.0      Asia           43.828      974.580338
# country            0
# year               0
# population         0
# continent          0
# life_expectancy    1
# gdp_per_capita     1
# dtype: int64
# country            0
# year               0
# population         0
# continent          0
# life_expectancy    0
# gdp_per_capita     0
# dtype: int64
#         country  year  population continent  life_expectancy  gdp_per_capita
# 0   Afghanistan  1952   8425333.0      Asia           28.801      779.445314
# 1   Afghanistan  1957   9240934.0      Asia           30.332      820.853030
# 2   Afghanistan  1962  10267083.0      Asia           39.854      853.100710
# 3   Afghanistan  1967  11537966.0      Asia           34.020      836.197138
# 4   Afghanistan  1972  13079460.0      Asia           36.088      739.981106
# 5   Afghanistan  1977  14880372.0      Asia           38.438      820.853030
# 6   Afghanistan  1982  12881816.0      Asia           39.854      978.011439
# 7   Afghanistan  1987  13867957.0      Asia           40.822      852.395945
# 8   Afghanistan  1992  16317921.0      Asia           41.674      649.341395
# 9   Afghanistan  1997  22227415.0      Asia           41.763      635.341351
# 10  Afghanistan  2002  25268405.0      Asia           42.129      726.734055
# 11  Afghanistan  2007  31889923.0      Asia           43.828      974.580338

# %%
#using pandas-- i want all of you to create a basic data analysis :-  # you can take use
#of llm
# year range
#number of countries
# number of continents



print("year range:",df["year"].min(),"to",df["year"].max())
print("Number of countries:",df["country"].nunique())
print("Number of continents:",df["continent"].nunique())


print("Average life expectancy:",df["life_expectancy"].mean())
print("Minimum life expectancy:",df["life_expectancy"].min())
print("Maximum life expectancy:",df["life_expectancy"].max())

print(df.describe())
# Out:
# year range: 1952 to 2007
# Number of countries: 142
# Number of continents: 5
# Average life expectancy: 59.474439366197174
# Minimum life expectancy: 23.599
# Maximum life expectancy: 82.603
#              year    population  life_expectancy  gdp_per_capita
# count  1704.00000  1.704000e+03      1704.000000     1704.000000
# mean   1979.50000  2.960121e+07        59.474439     7215.327081
# std      17.26533  1.061579e+08        12.917107     9857.454543
# min    1952.00000  6.001100e+04        23.599000      241.165876
# 25%    1965.75000  2.793664e+06        48.198000     1202.060309
# 50%    1979.50000  7.023596e+06        60.712500     3531.846988
# 75%    1993.25000  1.958522e+07        70.845500     9325.462346
# max    2007.00000  1.318683e+09        82.603000   113523.132900

# %%
#group and count-gdp population life expectancy


print(df["continent"].value_counts())

continent_summary = df.groupby("continent")[[      "life_expectancy",
    "population",
    "gdp_per_capita"
]].mean()

print(continent_summary)
#feature extraction
# Out:
# continent
# Africa      624
# Asia        396
# Europe      360
# Americas    300
# Oceania      24
# Name: count, dtype: int64
#            life_expectancy    population  gdp_per_capita
# continent
# Africa           48.865330  9.916003e+06     2193.754578
# Americas         64.658737  2.450479e+07     7136.110356
# Asia             60.064903  7.703872e+07     7902.150428
# Europe           71.903686  1.716976e+07    14469.475533
# Oceania          74.326208  8.874672e+06    18621.609223

# %%
latest_year = df["year"].max()
latest_df =df[df["year"]==latest_year].copy()

print("Latest year:",latest_year)
print(latest_df.head())
print(latest_df.shape)
# Out:
# Latest year: 2007
#         country  year  population continent  life_expectancy  gdp_per_capita
# 11  Afghanistan  2007  31889923.0      Asia           43.828      974.580338
# 23      Albania  2007   3600523.0    Europe           76.423     5937.029526
# 35      Algeria  2007  33333216.0    Africa           72.301     6223.367465
# 47       Angola  2007  12420476.0    Africa           42.731     4797.231267
# 59    Argentina  2007  40301927.0  Americas           75.320    12779.379640
# (142, 6)

# %%
# using the lib matplotlib #I need a bar chart that show me avg life expectancy  by continent

continent_life = latest_df.groupby("continent")["life_expectancy"].mean()

plt.bar(continent_life.index,continent_life.values)
plt.xlabel("Continent")
plt.ylabel("Average Life Expectancy")
plt.title("Average Life Expectancy by Continent")
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

url="https://raw.githubusercontent.com/plotly/datasets/master/gapminderDataFiveYear.csv"
df=pd.read_csv(url)

df=df.rename(columns={
    "lifeExp" : "life_expectancy",
    "pop" : "population",
    "gdpPercap" : "gdp_per_capita"
})

# temporal?
# line chart life expectancy over rime for 3 countries India ,China ,United states

selected_countries=["India","China","United States"]
trend_df =df[df["country"].isin(selected_countries)]

plt.figure(figsize=(9,5))


for country in selected_countries:
  country_data = trend_df[trend_df["country"]==country]
  plt.plot(country_data["year"],country_data["life_expectancy"],label=country)


plt.title("Life Expectancy Over Time for Selected Countries")
plt.xlabel("Year")
plt.ylabel("Life Expectancy")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#GDP per Capita VS Life Expectancy in 2007

import pandas as pd
import matplotlib.pyplot as plt

# Gapminder dataset load
url = "https://raw.githubusercontent.com/resbaz/r-novice-gapminder-files/master/data/gapminder-FiveYearData.csv"
df = pd.read_csv(url)

# 2007 ka data filter
data_2007 = df[df['year'] == 2007]

# Scatter plot
plt.figure(figsize=(8, 5))
plt.scatter(data_2007['gdpPercap'],
            data_2007['lifeExp'],
            alpha=0.7)

# Log scale on x-axis
plt.xscale('log')

# Labels and title
plt.title('GDP per Capita vs Life Expectancy in 2007')
plt.xlabel('GDP per Capita - log scale')
plt.ylabel('Life Expectancy')

plt.grid(True)
plt.show()

# %%
#Insights


#observation:line of china dips in 1959
#evidence:marker dips in 199 where area scale linearly
#meaning: plausible disaster (in this case famine)
